# %% [markdown]
# # Comprehension 내포
#
# - Comprehension은 한 줄짜리 반복문으로 새로운 컬렉션을 만드는 문법이다.
# - 대표적으로 list comprehension과 dict comprehension이 있다.
# - 반복문으로 값을 하나씩 추가하는 패턴을 더 짧고 읽기 좋게 표현할 수 있다.
#
# - list comprehension
# ```
# # list 생성
# [표현식 for 변수 in 반복가능한객체]
#
# # 조건 포함
# [표현식 for 변수 in 반복가능한객체 if 조건식]
# ```
#
# - dict comprehension
# ```
# # dict 생성
# {key표현식: value표현식 for 변수 in 반복가능한객체}
#
# # 조건 포함
# {key표현식: value표현식 for 변수 in 반복가능한객체 if 조건식}
# ```

# %% [markdown]
# ## 1. for 반복문과 list comprehension 비교
#
# 먼저 일반 `for` 반복문으로 리스트를 만든 뒤, 같은 결과를 list comprehension으로 바꿔 본다.

# %%
from builtins import range


# for 문
def make_numbers_with_for() -> list[int]:
    numbers: list[int] =[] # numbers 라는 변수를 선언, list형태, int 값만 저장
    for n in range(1, 6):
        numbers.append(n) # 뽑은 n 을 numbers 에 추가
    return numbers # 호출한 곳으로 numbers를 반환

print(make_numbers_with_for())

# list comprehension 으로 변경
def make_numbers_with_comprehension() -> list[int]:
    return [n*2 for n in range(1,6)] # for문의 n을 n으로 꺼내 리스트로 받고 반환한다.+ list 요소로 받자 마자 *2하여 리스트에 담음.

print(make_numbers_with_comprehension())
# Out:
# [1, 2, 3, 4, 5]
# [2, 4, 6, 8, 10]

# %% [markdown]
# ## 2. 조건식이 있는 list comprehension
#
# `if` 조건을 붙이면 원하는 요소만 필터링해서 리스트를 만들 수 있다.

# %%
#1 ~ 100 사이 정수 중 3의 배수만 골라서 list 요소로 추가
def make_numbers3() -> list[int]:
    return [n for n in range(1,101) if n % 3 == 0] # for 문으로 수를 뽑고, if 문에 부합하면, n의 list로 뽑음.

print("3의 배수 리스트: ", make_numbers3())
# Out:
# 3의 배수 리스트:  [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99]

# %%
# 전달된 list 에서 정수 (int)타입만 필터링 해서 반환
lst = [1, '123', '안녕', 22, {}, [], True, 333]

#object 타입: 아무 타입이나 가능(==Any)
def filter_int_values(values: list[object]) -> list[int]:
    # isinstance(value,type) -> bool
    # - value의 자료형이 type 과 일치하면 true, 아니면 false
    return [v for v in values if isinstance(v, int)]
print(filter_int_values(lst))
# Out:
# [1, 22, True, 333]

# %% [markdown]
# ## 3. 중첩 반복문 list comprehension
#
# 반복문이 중첩된 구조도 comprehension으로 표현할 수 있다. 다만 너무 복잡해지면 일반 반복문이 더 읽기 쉽다.

# %%
# 중첩 반복문
def make_positions() -> list[tuple[int,int]]:
    positions: list[tuple[int,int]] = []

    for row in range(3):# 0, 1 ,2
        for col in range(5): # 0, 1, 2, 3, 4
            positions.append((row, col)) # tuple로 묶기
    return positions
print(make_positions())
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (0, 4), (1, 0), (1, 1), (1, 2), (1, 3), (1, 4), (2, 0), (2, 1), (2, 2), (2, 3), (2, 4)]

# %%
# 중첩 comprehension
def make_positions_with_domprehension() -> list[tuple[int,int]]:
    return [(row, col) for row in range(3) for col in range (5)] # row 와 col을 꺼내서 (row, col) 에 저장하여 리스트로 저장

print(make_positions_with_domprehension())
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (0, 4), (1, 0), (1, 1), (1, 2), (1, 3), (1, 4), (2, 0), (2, 1), (2, 2), (2, 3), (2, 4)]

# %% [markdown]
# ## 4. dict comprehension
#
# `dict`도 comprehension으로 만들 수 있다.
#
# ```python
# {key식: value식 for 요소 in iterable}
# ```

# %%
# 제곱 함수
def make_square_map() -> dict[int, int]:
    return {k:k ** 2 for k in range(1, 6)} #k 를 꺼내어 key: value 형식(k:k) 딕셔너리로 저장, value는 제곱 값으로 저장하기( **2)
print(make_square_map())
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
# 문자열 리스트를 전달하여 {"문자열" : 문자열 길이} 형태의 dict 반환
def make_word_length_map(words: list[str]) -> dict[str, int]:
    # 일반적인 방법
    #result = {} # 결과를 저장할 딕셔너리 선언
    #for word in words:
    #    result[word] = len(word)
    #return result

    #comprehension
    return {word: len(word) for word in words if len(word) > 3}

words = ["hello", "배고파", "이거반복문이다"]
print(make_word_length_map(words))
# Out:
# {'hello': 5, '이거반복문이다': 7}

# %% [markdown]
# ## 5. list와 dict 변환
#
# `zip()`과 `dict()`를 함께 사용하면 두 리스트를 하나의 딕셔너리로 묶을 수 있다. 반대로 `dict.items()`와 unpacking을 사용하면 딕셔너리에서 key와 value 묶음을 분리할 수 있다.

# %%
def make_age_map() -> dict[str, int]:
    names: list[str] = ['홍길동', '신사임당', '이순신']
    ages: list[str] = [20, 40, 30]

    # zip(names, ages) == ['홍길동', '20', '신사임당', '40', '이순신', '40'] 인덱스가 같은 것끼리 짝을 지어 출력됨
    return dict(zip(names, ages)) # 딕셔너리 형태로 바꾸면 " 키: 밸류 " 형식으로 묶여서 출력이 됨

print("list -> dict: ", make_age_map())
# Out:
# list -> dict:  {'홍길동': 20, '신사임당': 40, '이순신': 30}

# %%
def split_age_map() -> tuple[tuple[str, ...], tuple[int, ...]]: # "..." : 0개부터 n개까지를 나타내는 가변 인자
    info: dict[str, int] = {'홍길동': 20, '신사임당': 40, '이순신': 30} # 이 딕셔너리 나누기
    print("info.items(): ", info.items()) # list[tuple]
    print(*info.items()) # * 의미: 풀기

    names, ages = zip(*info.items()) # 묶기
    return names, ages # 반환 시 튜플(튜플) 반환

print("dict -> tuple 묶음", split_age_map())
# Out:
# info.items():  dict_items([('홍길동', 20), ('신사임당', 40), ('이순신', 30)])
# ('홍길동', 20) ('신사임당', 40) ('이순신', 30)
# dict -> tuple 묶음 (('홍길동', '신사임당', '이순신'), (20, 40, 30))
